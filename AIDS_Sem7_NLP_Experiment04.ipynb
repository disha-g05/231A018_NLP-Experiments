# %% [markdown]
# <a href="https://colab.research.google.com/github/disha-g05/231A018_NLP-Experiments/blob/main/AIDS_Sem7_NLP_Experiment04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Morphological analysis

# %%
print("Disha Gawade, 231A018")
text = "The cats are running and jumping over the fences."
# Out:
# Disha Gawade, 231A018

# %%
print("Disha Gawade, 231A018")
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string
# Out:
# Disha Gawade, 231A018

# %%
print("Disha Gawade, 231A018")
# Download resouces
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
# Out:
# Disha Gawade, 231A018
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
print("Disha Gawade, 231A018")
import string
print(string.punctuation)
# Out:
# Disha Gawade, 231A018
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
# input text
# Step 1: preprocessing
print("Disha Gawade, 231A018")
text_lower = text.lower()
print(text_lower)
# Out:
# Disha Gawade, 231A018
# the cats are running and jumping over the fences.

# %%
# Step 2: Tokenization
print("Disha Gawade, 231A018")
tokens = word_tokenize(text_lower)

print(tokens)
# Out:
# Disha Gawade, 231A018
# ['the', 'cats', 'are', 'running', 'and', 'jumping', 'over', 'the', 'fences', '.']

# %%
print("Disha Gawade, 231A018")
text_clean=[]
for word in tokens:
  if word not in string.punctuation:
    text_clean.append(word)
print(text_clean)
# Out:
# Disha Gawade, 231A018
# ['the', 'cats', 'are', 'running', 'and', 'jumping', 'over', 'the', 'fences']

# %%
# Step 3: Identify roots (morpheme approximation using lemmatizer)
print("Disha Gawade, 231A018")
lemmatizer = WordNetLemmatizer()
lemmas = [lemmatizer.lemmatize(tok, pos='v') for tok in text_clean] #lemmatize as verbs

lemmas
# Out:
# Disha Gawade, 231A018
# ['the', 'cat', 'be', 'run', 'and', 'jump', 'over', 'the', 'fence']

# %%
print("Disha Gawade, 231A018")
[(token, lemma) for token, lemma in zip(tokens,lemmas)]
# Out:
# Disha Gawade, 231A018
# [('the', 'the'),
#  ('cats', 'cat'),
#  ('are', 'be'),
#  ('running', 'run'),
#  ('and', 'and'),
#  ('jumping', 'jump'),
#  ('over', 'over'),
#  ('the', 'the'),
#  ('fences', 'fence')]

# %%
# Step 4: Analyze tokens manually for derivational vs inflectional
print("Disha Gawade, 231A018")
morphological_info = {}
for token, lemma in zip(tokens, lemmas):
  if token != lemma:
    # This indicates some morphological change
    if token.endswith("ing"):
      analysis = "Inflectional: Present participle/continuous form of '{}'".format(lemma)
    elif token.endswith("er") or token.endswith("ation"):
      analysis = "Derivational: '{}' + -er/-ation -> modified form".format(lemma)
    else:
      analysis = "Inflectional or irregular form of '{}'".format(lemma)
  else:
    analysis = "Base/root form"
  morphological_info[token]=analysis
# Out:
# Disha Gawade, 231A018

# %%
print("Disha Gawade, 231A018")
morphological_info
# Out:
# Disha Gawade, 231A018
# {'the': 'Base/root form',
#  'cats': "Inflectional or irregular form of 'cat'",
#  'are': "Inflectional or irregular form of 'be'",
#  'running': "Inflectional: Present participle/continuous form of 'run'",
#  'and': 'Base/root form',
#  'jumping': "Inflectional: Present participle/continuous form of 'jump'",
#  'over': 'Base/root form',
#  'fences': "Inflectional or irregular form of 'fence'"}

# %% [markdown]
# additional practical on lemmatization

# %%
print("Disha Gawade, 231A018")
lemmatizer = WordNetLemmatizer()

words = [
    ("playing", "v"),
    ("played", "v"),
    ("studies", "v"),
    ("running", "v"),
    ("better", "a"),
    ("cars", "n")
]

pos_map = {
    "n": wordnet.NOUN,
    "v": wordnet.VERB,
    "a": wordnet.ADJ,
    "r": wordnet.ADV
}
# Out:
# Disha Gawade, 231A018
