# %% [markdown]
# <a href="https://colab.research.google.com/github/disha-g05/231A018_NLP-Experiments/blob/main/AIDS_Sem7_NLP_Experiment06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Libraries

# %%
print("Disha Gawade 231A018")
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import UnigramTagger, BigramTagger, pos_tag
from nltk.corpus import treebank
from nltk import pos_tag_sents
# Out:
# Disha Gawade 231A018

# %%
print("Disha Gawade 231A018")
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab')
nltk.download('treebank')
nltk.download('tagsets_json')
# Out:
# Disha Gawade 231A018
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [nltk_data] Downloading package tagsets_json to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets_json.zip.
# True

# %%
# Tagging a sample text
print("Disha Gawade 231A018")
sample_text = "He is reading a book. Book a flight ticket for me."

# Tokenize the text
tokens = word_tokenize(sample_text)
# Out:
# Disha Gawade 231A018

# %%
print("Disha Gawade 231A018")
# Rule based POS tagging
rule_based_tags = pos_tag(tokens)
# Out:
# Disha Gawade 231A018

# %%
print("Disha Gawade 231A018")
print(rule_based_tags)
# Out:
# Disha Gawade 231A018
# [('He', 'PRP'), ('is', 'VBZ'), ('reading', 'VBG'), ('a', 'DT'), ('book', 'NN'), ('.', '.'), ('Book', 'VB'), ('a', 'DT'), ('flight', 'NN'), ('ticket', 'NN'), ('for', 'IN'), ('me', 'PRP'), ('.', '.')]

# %%
print("Disha Gawade 231A018")
nltk.help.upenn_tagset('VBG')
# Out:
# Disha Gawade 231A018
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...

# %%
print("Disha Gawade 231A018")
# Statistical tagging using treebank corpus
train_sents = treebank.tagged_sents()
# Unigram tagger
unigram_tagger = UnigramTagger(train_sents)
unigram_tags = unigram_tagger.tag(tokens)

# Bigram tagger
bigram_tagger = BigramTagger(train_sents, backoff=unigram_tagger)
bigram_tags = bigram_tagger.tag(tokens)
# Out:
# Disha Gawade 231A018

# %%
print("Disha Gawade 231A018")
bigram_tags
# Out:
# Disha Gawade 231A018
# [('He', 'PRP'),
#  ('is', 'VBZ'),
#  ('reading', 'NN'),
#  ('a', 'DT'),
#  ('book', 'NN'),
#  ('.', '.'),
#  ('Book', 'NNP'),
#  ('a', 'DT'),
#  ('flight', None),
#  ('ticket', 'NN'),
#  ('for', 'IN'),
#  ('me', 'PRP'),
#  ('.', '.')]

# %%
print("Disha Gawade 231A018")
unigram_tags
# Out:
# Disha Gawade 231A018
# [('He', 'PRP'),
#  ('is', 'VBZ'),
#  ('reading', 'NN'),
#  ('a', 'DT'),
#  ('book', 'NN'),
#  ('.', '.'),
#  ('Book', 'NNP'),
#  ('a', 'DT'),
#  ('flight', None),
#  ('ticket', 'NN'),
#  ('for', 'IN'),
#  ('me', 'PRP'),
#  ('.', '.')]

# %%
print("Disha Gawade 231A018")
print("Original Sentence: ", sample_text)
print("\nRule_Based POS Tagging (statistical):")
print(rule_based_tags)
print("\nUnigram POS Tagging")
print(unigram_tags)
print("\nBigram POS Tagging")
print(bigram_tags)
# Out:
# Disha Gawade 231A018
# Original Sentence:  He is reading a book. Book a flight ticket for me.
#
# Rule_Based POS Tagging (statistical):
# [('He', 'PRP'), ('is', 'VBZ'), ('reading', 'VBG'), ('a', 'DT'), ('book', 'NN'), ('.', '.'), ('Book', 'VB'), ('a', 'DT'), ('flight', 'NN'), ('ticket', 'NN'), ('for', 'IN'), ('me', 'PRP'), ('.', '.')]
#
# Unigram POS Tagging
# [('He', 'PRP'), ('is', 'VBZ'), ('reading', 'NN'), ('a', 'DT'), ('book', 'NN'), ('.', '.'), ('Book', 'NNP'), ('a', 'DT'), ('flight', None), ('ticket', 'NN'), ('for', 'IN'), ('me', 'PRP'), ('.', '.')]
#
# Bigram POS Tagging
# [('He', 'PRP'), ('is', 'VBZ'), ('reading', 'NN'), ('a', 'DT'), ('book', 'NN'), ('.', '.'), ('Book', 'NNP'), ('a', 'DT'), ('flight', None), ('ticket', 'NN'), ('for', 'IN'), ('me', 'PRP'), ('.', '.')]

# %%
print("Disha Gawade 231A018")
# Evaluate the performance of each tagger using Treebank
test_sents = treebank.tagged_sents()[1000:]
unigram_acc = unigram_tagger.evaluate(test_sents)
bigram_acc = bigram_tagger.evaluate(test_sents)

print(f"\nUnigram tagger accuracy: {unigram_acc * 100: .2f}%")
print(f"\nBigram tagger accuracy: {bigram_acc * 100: .2f}%")
# Out:
# Disha Gawade 231A018
# /tmp/ipykernel_3643/3278018228.py:4: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   unigram_acc = unigram_tagger.evaluate(test_sents)
# /tmp/ipykernel_3643/3278018228.py:5: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   bigram_acc = bigram_tagger.evaluate(test_sents)
# Unigram tagger accuracy:  96.01%
#
# Bigram tagger accuracy:  98.52%
