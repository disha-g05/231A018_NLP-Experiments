# %%
print("Disha Gawade 231A018")
import nltk
import matplotlib.pyplot as plt
import random
# Out:
# Disha Gawade 231A018

# %%
print("Disha Gawade 231A018")
nltk.download('twitter_samples')
# Out:
# Disha Gawade 231A018
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
print("Disha Gawade 231A018")
from nltk.corpus import twitter_samples
# Out:
# Disha Gawade 231A018

# %%
print("Disha Gawade 231A018")
tweets = twitter_samples.strings()
type(tweets)
# Out:
# Disha Gawade 231A018
# list

# %%
print("Disha Gawade 231A018")
len(tweets)
# Out:
# Disha Gawade 231A018
# 30000

# %%
print("Disha Gawade 231A018")
import pandas as pd
all_tweets = pd.DataFrame(tweets,columns=["Tweets"])
all_tweets.head()
# Out:
# Disha Gawade 231A018
#                                               Tweets
# 0                                hopeless for tmr :(
# 1  Everything in the kids section of IKEA is so c...
# 2  @Hegelbon That heart sliding into the waste ba...
# 3  “@ketchBurning: I hate Japanese call him "bani...
# 4           Dang starting next week I have "work" :(

# %%
print("Disha Gawade 231A018")
print("Length of the first tweet:", len(tweets[0]))
# Out:
# Disha Gawade 231A018
# Length of the first tweet: 19

# %%
print("Disha Gawade 231A018")
twitter_samples.fileids()
# Out:
# Disha Gawade 231A018
# ['negative_tweets.json', 'positive_tweets.json', 'tweets.20150430-223406.json']

# %%
print("Disha Gawade 231A018")
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')
# Out:
# Disha Gawade 231A018

# %%
print("Disha Gawade 231A018")
type(positive_tweets)
# Out:
# Disha Gawade 231A018
# list

# %%
print("Disha Gawade 231A018")
positive_tweets[0]
# Out:
# Disha Gawade 231A018
# '#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)'

# %%
print("Disha Gawade 231A018")
negative_tweets[0]
# Out:
# Disha Gawade 231A018
# 'hopeless for tmr :('

# %%
print("Disha Gawade 231A018")
print('Number of positive tweets: ', len(positive_tweets))
print('Number of negative tweets: ', len(negative_tweets))
# Out:
# Disha Gawade 231A018
# Number of positive tweets:  5000
# Number of negative tweets:  5000

# %%
print("Disha Gawade 231A018")
import pandas as pd
positive_tweets = pd.DataFrame(positive_tweets,columns=["Tweets"])
positive_tweets["Sentiments"] = "Positive"
# Out:
# Disha Gawade 231A018

# %%
print("Disha Gawade 231A018")
positive_tweets.head()
# Out:
# Disha Gawade 231A018
#                                               Tweets Sentiments
# 0  #FollowFriday @France_Inte @PKuchly57 @Milipol...   Positive
# 1  @Lamb2ja Hey James! How odd :/ Please call our...   Positive
# 2  @DespiteOfficial we had a listen last night :)...   Positive
# 3                               @97sides CONGRATS :)   Positive
# 4  yeaaaah yippppy!!!  my accnt verified rqst has...   Positive

# %%
print("Disha Gawade 231A018")
negative_tweets = pd.DataFrame(negative_tweets,columns=["Tweets"])
negative_tweets["Sentiments"] = "Negative"
# Out:
# Disha Gawade 231A018

# %%
print("Disha Gawade 231A018")
negative_tweets.head()
# Out:
# Disha Gawade 231A018
#                                               Tweets Sentiments
# 0                                hopeless for tmr :(   Negative
# 1  Everything in the kids section of IKEA is so c...   Negative
# 2  @Hegelbon That heart sliding into the waste ba...   Negative
# 3  “@ketchBurning: I hate Japanese call him "bani...   Negative
# 4           Dang starting next week I have "work" :(   Negative

# %%
print("Disha Gawade 231A018")
tweets = pd.concat([positive_tweets , negative_tweets], ignore_index=True)
tweets = tweets.sample(frac=1).reset_index(drop=True)
tweets
# Out:
# Disha Gawade 231A018
#                                                  Tweets Sentiments
# 0     Stats for the day have arrived. 1 new follower...   Positive
# 1     Hi BAM ! @BarsAndMelody \nCan you follow my be...   Positive
# 2     that means i will be on the low limit table fo...   Negative
# 3     @wendykims @Joix05 @GiladMillo some people nee...   Negative
# 4     @shiningstarniti r u angry....now m feeling so...   Negative
# ...                                                 ...        ...
# 9995  @TeamGtwy Thanks for adding us to your list! :...   Positive
# 9996  Is this true? I doubt it is :( #ZaynIsComingBa...   Negative
# 9997  Oh lovely lovelayyy! Thanks! It is ok about th...   Positive
# 9998  @LorSaguinsin you should study at McDo. Strong...   Positive
# 9999               homed &amp; omg I'm so tanned!!! :-(   Negative
#
# [10000 rows x 2 columns]

# %%
print("Disha Gawade 231A018")
print(tweets[tweets["Sentiments"]=="Positive"].value_counts().sum())
print(tweets[tweets["Sentiments"]=="Negative"].value_counts().sum())
# Out:
# Disha Gawade 231A018
# 5000
# 5000

# %% [markdown]
# Visualizing

# %%
print("Disha Gawade 231A018")
y_positive = tweets[tweets["Sentiments"]=="Positive"].value_counts().sum()
y_negative = tweets[tweets["Sentiments"]=="Negative"].value_counts().sum()
print(y_positive, y_negative)
# Out:
# Disha Gawade 231A018
# 5000 5000

# %% [markdown]
# Positive and Negative is equal in no so data is balanced. Both positive and negative have equal no of data.

# %%
print("Disha Gawade 231A018")
#fig with custom size
fig = plt.figure(figsize=(4,4))
#labels for the two class
labels = ['Positives','Negative']
#sizes for each slide
sizes = [y_positive, y_negative]
#pie chart
plt.bar(labels,sizes)
#display
plt.show()
# Out:
# Disha Gawade 231A018

# %% [markdown]
# Preprocessing raw data:
# Tokenization, lowercasing, removing stop words and punctuation, stemming

# %%
print("Disha Gawade 231A018")
#selected sample. complex enough to exemplify each step
tweet1 = all_tweets.iloc[512]
tweet1["Tweets"]
# Out:
# Disha Gawade 231A018
# "#newbethvideo i love you sooo much! But... I live in Greece so I dont think I'm gonna win :( But always hope!!!! &lt;3"

# %% [markdown]
# importing libraries for tex preprocessing

# %%
print("Disha Gawade 231A018")
import re       # for regular expression operations
import string   # for string operations
from nltk.corpus import stopwords     #module for stop words that come with nltk
from nltk.stem import PorterStemmer   #module for stemming
from nltk.tokenize import TweetTokenizer    #module for tokenizing strings
# Out:
# Disha Gawade 231A018

# %% [markdown]
# remove hyperlinks ,twitter marks and styles

# %%
print("Disha Gawade 231A018")
# remove old style retweet text "RT"
tweet2 = re.sub(r'^RT[\s]+','', tweet1["Tweets"])

#remove hyperlinks
tweet2 = re.sub(r'https?://[^\s\n\r]+','',tweet2)

#remove hashtags. only remove the hash # sign from the word
tweet2 = re.sub(r'#','',tweet2)
tweet2 = re.sub(r'@\w+','',tweet2)
tweet2 = re.sub(f'[:)|(:]','',tweet2)
print(tweet1["Tweets"])
print("\nCleaned Tweet: \n",tweet2)
# Out:
# Disha Gawade 231A018
# #newbethvideo i love you sooo much! But... I live in Greece so I dont think I'm gonna win :( But always hope!!!! &lt;3
#
# Cleaned Tweet:
#  newbethvideo i love you sooo much! But... I live in Greece so I dont think I'm gonna win  But always hope!!!! &lt;3

# %% [markdown]
# Tokenize

# %%
print("Disha Gawade 231A018")
#initiate tokenizer class
tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
#tokenize tweets
tweet_tokens = tokenizer.tokenize(tweet2)
print()
print('Tokenized string:\n')
print(tweet_tokens)
# Out:
# Disha Gawade 231A018
#
# Tokenized string:
#
# ['newbethvideo', 'i', 'love', 'you', 'sooo', 'much', '!', 'but', '...', 'i', 'live', 'in', 'greece', 'so', 'i', 'dont', 'think', "i'm", 'gonna', 'win', 'but', 'always', 'hope', '!', '!', '!', '<3']

# %% [markdown]
# Remove stop words and punctuations

# %%
print("Disha Gawade 231A018")
#download stopwords from nltk
nltk.download('stopwords')
# Out:
# Disha Gawade 231A018
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print("Disha Gawade 231A018")
#import english stop words list from nltk
stopwords_english = stopwords.words('english')

print('Stop words\n')
print(stopwords_english)

print('\nPunctuation\n')
print(string.punctuation)
# Out:
# Disha Gawade 231A018
# Stop words
#
# ...

# %%
print("Disha Gawade 231A018")
print(tweet_tokens)
print()

tweets_clean = []

for word in tweet_tokens: # go throug ever word in your tokens list
  if(word not in stopwords_english and  # remove stopwords
      word not in string.punctuation):  #remove punctuation
    tweets_clean.append(word)

print('removed stop words and punctuation')
print(tweets_clean)
# Out:
# Disha Gawade 231A018
# ['newbethvideo', 'i', 'love', 'you', 'sooo', 'much', '!', 'but', '...', 'i', 'live', 'in', 'greece', 'so', 'i', 'dont', 'think', "i'm", 'gonna', 'win', 'but', 'always', 'hope', '!', '!', '!', '<3']
#
# removed stop words and punctuation
# ['newbethvideo', 'love', 'sooo', 'much', '...', 'live', 'greece', 'dont', 'think', 'gonna', 'win', 'always', 'hope', '<3']

# %% [markdown]
# create function to process tweet

# %%
print("Disha Gawade 231A018")
def process_tweet(tweet):
  tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)

  tweet = re.sub(r'^RT[\s]+','', tweet)

  #remove hyperlinks
  tweet = re.sub(r'https?://[^\s\n\r]+','',tweet)

  #remove hashtags. only remove the hash # sign from the word
  tweet = re.sub(r'#','',tweet)
  tweet = re.sub(r'@\w+','',tweet)
  tweet = re.sub(f'[:)|(:]','',tweet)

  tweet_tokens = tokenizer.tokenize(tweet)
  stopwords_english = stopwords.words('english')
  tweets_clean = []

  for word in tweet_tokens: # go throug ever word in your tokens list
    if(word not in stopwords_english and  # remove stopwords
        word not in string.punctuation):
        tweets_clean.append(word)
  return tweets_clean
# Out:
# Disha Gawade 231A018

# %%
print("Disha Gawade 231A018")
tweet1 = all_tweets.iloc[512]
tweet = tweet1["Tweets"]
print(tweet)
print(process_tweet(tweet))
# Out:
# Disha Gawade 231A018
# #newbethvideo i love you sooo much! But... I live in Greece so I dont think I'm gonna win :( But always hope!!!! &lt;3
# ['newbethvideo', 'love', 'sooo', 'much', '...', 'live', 'greece', 'dont', 'think', 'gonna', 'win', 'always', 'hope', '<3']

# %%
print("Disha Gawade 231A018")
processed_tweets = all_tweets['Tweets'].apply(process_tweet)
all_tweets['Tweets_processed']=processed_tweets
pd.set_option('display.max_colwidth',None)
all_tweets
# Out:
# Disha Gawade 231A018
#                                                                                                                                               Tweets  \
# 0                                                                                                                                hopeless for tmr :(
# 1                                                              Everything in the kids section of IKEA is so cute. Shame I'm nearly 19 in 2 months :(
# 2                                                                                             @Hegelbon That heart sliding into the waste basket. :(
# 3                                                                                   “@ketchBurning: I hate Japanese call him "bani" :( :(”\n\nMe too
# 4                                                                                                           Dang starting next week I have "work" :(
# ...

# %%
print("Disha Gawade 231A018")
tweets['Tweets_processed'] = tweets['Tweets'].apply(process_tweet)
display(tweets[['Tweets_processed', 'Sentiments']])
# Out:
# Disha Gawade 231A018
#                                                                                 Tweets_processed  \
# 0                                      [stats, day, arrived, 1, new, follower, unfollowers, via]
# 1                       [hi, bam, follow, bestfriend, loves, lot, see, warsaw, <3, love, <3, x3]
# 2                                                                 [means, low, limit, table, xd]
# 3                               [people, need, talk-kama, hawako, around, waa, kimaaani, prisss]
# 4                               [r, u, angry, ..., feeling, disappointed, .., mm, ..., srry, ..]
# ...                                                                                          ...
# 9995  [thanks, adding, us, list, make, sure, keep, touch, news, light, bulbs, made, corn, waste]
# 9996                                                   [true, doubt, zayniscomingbackonjuly, 26]
# ...
